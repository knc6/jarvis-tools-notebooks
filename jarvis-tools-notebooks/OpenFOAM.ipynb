# %% [markdown]
# <a href="https://colab.research.google.com/github/knc6/jarvis-tools-notebooks/blob/master/jarvis-tools-notebooks/OpenFOAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://develop.openfoam.com/Development/openfoam/-/issues/2788

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:15
# 🔁 Restarting kernel...

# %%
# !conda install openfoam -c conda-forge
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - openfoam
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %% [markdown]
# https://develop.openfoam.com/Development/openfoam/-/wikis/precompiled/debian

# %%
# !curl -s https://dl.openfoam.com/add-debian-repo.sh | sudo bash
# Out:
# Detected distribution code-name: jammy
# Added /etc/apt/sources.list.d/openfoam.list
# Importing openfoam gpg key... done
# Added /etc/apt/trusted.gpg.d/openfoam.gpg
# Running apt-get update... done
#
# The repository is setup! You can now install packages.

# %%
# !wget -q -O - https://dl.openfoam.com/add-debian-repo.sh | sudo bash
# Out:
# Detected distribution code-name: jammy
# Overwrote /etc/apt/sources.list.d/openfoam.list
# Importing openfoam gpg key... done
# Overwrote /etc/apt/trusted.gpg.d/openfoam.gpg
# Running apt-get update... done
#
# The repository is setup! You can now install packages.

# %%
# !apt-get install openfoam2406-default
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   flex libcgal-dev libfftw3-bin libfftw3-dev libfftw3-double3 libfftw3-long3 libfftw3-quad3
#   libfftw3-single3 libfl-dev libfl2 libgmp-dev libgmpxx4ldbl libmpfr-dev libptscotch-6.1
#   libptscotch-dev libscotch-dev openfoam-selector openfoam2406 openfoam2406-common openfoam2406-dev
#   openfoam2406-source openfoam2406-tools openfoam2406-tutorials
# Suggested packages:
#   bison flex-doc libmpfi-dev libntl-dev libfftw3-doc gmp-doc libgmp10-doc libmpfr-doc gnuplot
# The following NEW packages will be installed:
#   flex libcgal-dev libfftw3-bin libfftw3-dev libfftw3-double3 libfftw3-long3 libfftw3-quad3
#   libfftw3-single3 libfl-dev libfl2 libgmp-dev libgmpxx4ldbl libmpfr-dev libptscotch-6.1
#   libptscotch-dev libscotch-dev openfoam-selector openfoam2406 openfoam2406-common
# ...

# %%
# !openfoam2406
# Out:
# bash: cannot set terminal process group (493): Inappropriate ioctl for device
# bash: no job control in this shell
# openfoam = /usr/lib/openfoam/openfoam2406
#
#  * Using:     OpenFOAM-v2406 (2406) - visit www.openfoam.com
#  * Build:     _9bfe8264-20241212 (patch=241212)
#  * Arch:      label=32;scalar=64
#  * Platform:  linux64GccDPInt32Opt (mpi=sys-openmpi)
#
# OpenFOAM shell session - use 'exit' to quit
#
# openfoam2406:/content/
# root# exit
# exit

# %%
# !which openfoam2406
# Out:
# /usr/bin/openfoam2406

# %%
import os
os.chdir("/usr/lib/openfoam/openfoam2406/tutorials/incompressible/icoFoam/cavity/cavity/")

# %%
# !ls /usr/lib/openfoam/openfoam2406/tutorials/incompressible/icoFoam/cavity/cavity/
# Out:
# 0  constant  system

# %%
# !blockMesh
# Out:
# /bin/bash: line 1: blockMesh: command not found

# %%
# !which icoFoam

# %%
# !ls /usr/lib/openfoam/openfoam2406/applications/
# Out:
# Allwmake  solvers  test  tools	utilities

# %%
# !apt-get install build-essential cmake git ca-certificates flex
# !sh -c "wget -O - https://dl.openfoam.org/gpg.key > /etc/apt/trusted.gpg.d/openfoam.asc"
# !add-apt-repository http://dl.openfoam.org/ubuntu
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# ca-certificates is already the newest version (20240203~22.04.1).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# git is already the newest version (1:2.34.1-1ubuntu1.12).
# The following additional packages will be installed:
#   libfl-dev libfl2
# Suggested packages:
#   bison flex-doc
# The following NEW packages will be installed:
#   flex libfl-dev libfl2
# 0 upgraded, 3 newly installed, 0 to remove and 29 not upgraded.
# Need to get 324 kB of archives.
# After this operation, 1,148 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 flex amd64 2.6.4-8build2 [307 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfl2 amd64 2.6.4-8build2 [10.7 kB]
# ...

# %%
# !apt install openfoam-deps paraview-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   aglfn avahi-daemon base58 bind9-host bind9-libs cython3 fonts-dejavu-core fonts-lyx geoclue-2.0
#   glib-networking glib-networking-common glib-networking-services gnuplot gnuplot-data gnuplot-qt
#   gsettings-desktop-schemas iio-sensor-proxy libavahi-core7 libavahi-glib1 libavfilter-dev
#   libdaemon0 libdouble-conversion-dev libdraco4 libegl-dev libeigen3-dev libevdev2 libgdal30
#   libgeos++-dev libgl-dev libgl2ps-dev libglew-dev libglu1-mesa libglu1-mesa-dev libglx-dev
#   libgudev-1.0-0 libhyphen0 libice-dev libimagequant0 libinput-bin libinput10 libjson-glib-1.0-0
#   libjson-glib-1.0-common liblaszip-api8 liblaszip-dev liblaszip8 liblbfgsb0 liblmdb0 liblua5.4-0
#   libmaxminddb0 libmbim-glib4 libmbim-proxy libmd4c0 libmm-glib0 libmtdev1 libnl-genl-3-200
# ...

# %%
# !runApplication
# Out:
# /bin/bash: line 1: runApplication: command not found

# %%
# !apt-get update
# !apt-get install -y software-properties-common
# !add-apt-repository -y ppa:openfoam/openfoam8
# !apt-get install -y openfoam8
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,649 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,688 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
2+2
# Out:
# 4
